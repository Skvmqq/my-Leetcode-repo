# %% [markdown]
# Day 73 | Binary Search Tree Operations 🌳
#
#
#     Insert into a Binary Search Tree
#     Search in a Binary Search Tree
#
# Problem :-
#
#     Insert into BST
#     Insert a value into the correct position while maintaining the BST property.
#
# Search in BST
#     Find a node with a given value and return the subtree rooted at that node.
#
# Key Idea:
#     In a BST:
#
#     Values smaller than the current node go to the left subtree
#
#     Values greater than the current node go to the right subtree
#
# Logic:
#
#     Insert:
#
#         If the tree is empty, create a new node.
#
#         If the value is smaller, insert into the left subtree.
#
#         Otherwise, insert into the right subtree.
#
#     Search:
#
#         If the current node matches the value, return it.
#
#         If the value is smaller, search the left subtree.
#
#         Otherwise, search the right subtree.
#
# Complexity:
#
#     Time: O(h) where h is the height of the tree
#
#     Space: O(h) (recursion stack)

# %%
from collections import deque

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right


class Solution:

    
    def searchBST(self, root, val):

        if not root or root.val == val:
            return root

        if val < root.val:
            return self.searchBST(root.left, val)

        else:
            return self.searchBST(root.right, val)


    
    def insertIntoBST(self, root, val):

        if not root:
            return TreeNode(val)

        if val < root.val:
            root.left = self.insertIntoBST(root.left, val)
        else:
            root.right = self.insertIntoBST(root.right, val)

        return root


def print_tree(root):

    queue = deque([root])

    while queue:
        node = queue.popleft()

        if node:
            print(node.val, end=" ")
            queue.append(node.left)
            queue.append(node.right)
        else:
            print("null", end=" ")

    print("\n")




root = TreeNode(4)
root.left = TreeNode(2)
root.right = TreeNode(7)

root.left.left = TreeNode(1)
root.left.right = TreeNode(3)


sol = Solution()

print("Original Tree:")
print_tree(root)




node = sol.searchBST(root, 2)

print("Search Result (subtree from 2):")
print_tree(node)




root = sol.insertIntoBST(root, 5)

print("Tree after inserting 5:")
print_tree(root)
# Out:
# Original Tree:
# 4 2 7 1 3 null null null null null null
#
# Search Result (subtree from 2):
# 2 1 3 null null null null
#
# Tree after inserting 5:
# 4 2 7 1 3 5 null null null null null null null
